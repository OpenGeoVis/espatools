# %%
# Import the espatools module for raster I/O
import espatools
# Use matplotlib for simple plotting
import matplotlib.pyplot as plt

# %%
xmlfile = 'LC081210652018073101RT-SC20180802013328/LC08_L1TP_121065_20180731_20180731_01_RT.xml'
#xmlfile = 'LC081210652018073101RT-SC20180802013328/simple.xml'
reader = espatools.RasterSetReader(filename=xmlfile)

# %%
raster = reader.Read(cast=False)#, allowed=['sr_aerosol', 'sr_band7'])
bands = raster.bands
bands
# Out:
# {'pixel_qa': <espatools.raster.Band at 0x111a342b0>,
#  'radsat_qa': <espatools.raster.Band at 0x111a34940>,
#  'sr_band1': <espatools.raster.Band at 0x111a34dd8>,
#  'sr_band2': <espatools.raster.Band at 0x111b26278>,
#  'sr_band3': <espatools.raster.Band at 0x111b266d8>,
#  'sr_band4': <espatools.raster.Band at 0x111b26b38>,
#  'sr_band5': <espatools.raster.Band at 0x111b26f98>,
#  'sr_band6': <espatools.raster.Band at 0x10e72d438>,
#  'sr_band7': <espatools.raster.Band at 0x10e72d898>,
#  'sr_aerosol': <espatools.raster.Band at 0x10e72dda0>}

# %%
for n,b in bands.items():
    print(b.data.dtype)
# Out:
# uint16
# uint16
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# uint8

# %%
b = bands.get('sr_aerosol')

plt.figure(figsize=(10,10))
plt.imshow(b.data)
plt.title(b.name)
plt.savefig('aer.png')
plt.show()

# %%
color = raster.GetRGB()

# %%
plt.figure(figsize=(10,10))
plt.imshow(color)
plt.title('RGB Color')
plt.savefig('RGB.png')
plt.show()

# %%
raster.global_metadata.satellite
# Out:
# 'LANDSAT_8'

# %%
raster.nsamps
# Out:
# 7581

# %%
raster.nlines
# Out:
# 7721

# %%
color.shape
# Out:
# (7721, 7581, 3)

# %%
raster.global_metadata.projection_information.corner_point[0].x
# Out:
# 108900.0
